# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA as SKlearnPCA

iris = load_iris()
X = iris.data
y = iris.target

pca = SKlearnPCA(n_components = 2)
labels = pca.fit_transform(X)

print('Shape of data:',X.shape)
print('Shape of transformed data:',labels.shape)

pc1 = labels[:,0]
pc2 = labels[:,1]

plt.scatter(pc1,pc2, c=y, cmap='jet')
plt.xlabel("PC1")
plt.xlabel("PC2")
plt.show()
# Out:
# Shape of data: (150, 4)
# Shape of transformed data: (150, 2)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis

iris = load_iris()
X = iris.data
y = iris.target

pca =  LinearDiscriminantAnalysis(n_components = 2)
labels = pca.fit_transform(X, y)

print('Shape of data:',X.shape)
print('Shape of transformed data:',labels.shape)

pc1 = labels[:,0]
pc2 = labels[:,1]

plt.scatter(pc1,pc2, c=y, cmap='jet')
plt.xlabel("PC1")
plt.xlabel("PC2")
plt.show()
# Out:
# Shape of data: (150, 4)
# Shape of transformed data: (150, 2)
